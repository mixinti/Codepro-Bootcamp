# %%
#Retroalimentacion

#Llamar a una funcion:

palabra = "Hola"

def imprimir_palabra():
    print(palabra)

imprimir_palabra()

#Funcion que recibe dos numeros y suma:

#Opcion 1

numero1 = int(input("Ingresa un numero"))
numero2 = int(input("Ingresa un numero"))

def sumar(n1, n2):
    n3 = n1 + n2
    print(n3)

sumar(numero1, numero2)

#Opcion 2
def sumar(n1, n2):
    print(n1 + n2)

sumar (2,2)
# Out:
# Hola
# 10
# 4

# %%
#Crea una funcion que reciba dos letras (parametros) y que verifique si son iguales:
# 1. Si son iguales: imprimir "Las letras son iguales"
# 2. De lo contrario, imprimir: "Las letras son diferentes"

letra1 = input("Ingrese la primera letra")
letra2 = input("Ingrese la segunda letra")

def letras(l1, l2):
    if l1 == l2:
        print("Las letras on iguales")

    else:
        print("Las letras son diferentes")

letras(letra1, letra2)
# Out:
# Las letras son diferentes

# %%
#Challenge 1

palabraa = (input("Ingrese una palabra"))
numero = int(input("Ingrese un numero"))

def compara(palabraa, numero):
    if len(palabraa) == numero:
        return True
    else:
        return False
    
compara(palabraa, numero)
# Out:
# True

# %%
#Challenge 2

palabra_ejemplo = input ("Ingrese una palabra")
condicion = "a"

def revisar(letra, cond):
    if cond in letra:
        return (f"[{cond}]")
    else:
        return cond
    
revisar(palabra_ejemplo, condicion)
# Out:
# '[a]'

# %%
#Challenge 3

palabras_ingresadas = []

for i in range(3):
    word = input("Ingresa palabra")
    lista_palabra = list(word)
    palabras_ingresadas.append(lista_palabra)
    print(palabras_ingresadas)
# Out:
# [['p', 'i', 'n', 'g', 'u', 'i', 'n', 'o']]
# [['p', 'i', 'n', 'g', 'u', 'i', 'n', 'o'], ['g', 'a', 't', 'o']]
# [['p', 'i', 'n', 'g', 'u', 'i', 'n', 'o'], ['g', 'a', 't', 'o'], ['z', 'o', 'r', 'r', 'o']]

# %%
#Challenge 4

def grilla(lista_de_listas):
    for i in lista_de_listas:
        print(list(i))

lista_principal = [['p','e','n','g','u','i','n'],['h','o','l','a'],['c','h','a','u']]

grilla(lista_principal)
# Out:
# ['p', 'e', 'n', 'g', 'u', 'i', 'n']
# ['h', 'o', 'l', 'a']
# ['c', 'h', 'a', 'u']

# %%
letras_verificadas = []
cantidad_letras = 5
palabra_secreta = "salto"

def verificador_palabra(palabra_ingresada, palabra_secreta):
    for i in range(cantidad_letras):
        las_palabras_son_iguales = palabra_ingresada[i] == palabra_secreta[i]
        la_letra_existe_en_la_palabra = palabra_ingresada [i] in palabra_secreta
        if las_palabras_son_iguales:
            letras_verificadas.append(f"[{palabra_ingresada[i]}]")
        
        elif la_letra_existe_en_la_palabra:
            letras_verificadas.append(f"({palabra_ingresada[i]})")
        
        else:
            letras_verificadas.append(palabra_ingresada[i])
        
    return letras_verificadas

print(verificador_palabra('holas', 'calor'))
# Out:
# ['h', '(o)', '[l]', '(a)', 's']

# %%
intentos = 0

while intentos < 6:
    print(f"te quedan {6 - intentos} intentos")
    intentos = intentos + 1
    palabra_ingresada = input("Ingrese una palabra")
    print(f"la palabra ingresada es: {palabra_ingresada}")
# Out:
# te quedan 6 intentos
# la palabra ingresada es: hola
# te quedan 5 intentos
# la palabra ingresada es: chau
# te quedan 4 intentos
# la palabra ingresada es: aa
# te quedan 3 intentos
# la palabra ingresada es: ee
# te quedan 2 intentos
# la palabra ingresada es: i
# te quedan 1 intentos
# la palabra ingresada es: o
